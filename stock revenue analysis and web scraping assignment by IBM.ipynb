# %% [markdown]
# # Web Scraping

# %% [markdown]
# ### Question 1 - Extracting Tesla Stock Data Using yfinance - 2 Points

# %%
import yfinance as yf
import requests
from bs4 import BeautifulSoup
tesla_stock_data = yf.download('TSLA', start='2022-01-01', end='2023-01-01')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
tesla_stock_data
# Out:
#                   Open        High         Low       Close   Adj Close
# Date
# 2022-01-03  382.583344  400.356659  378.679993  399.926666  399.926666  \
# 2022-01-04  396.516663  402.666656  374.350006  383.196655  383.196655
# 2022-01-05  382.216675  390.113342  360.336670  362.706665  362.706665
# 2022-01-06  359.000000  362.666656  340.166656  354.899994  354.899994
# 2022-01-07  360.123322  360.309998  336.666656  342.320007  342.320007
# ...                ...         ...         ...         ...         ...
# 2022-12-23  126.370003  128.619995  121.019997  123.150002  123.150002
# 2022-12-27  117.500000  119.669998  108.760002  109.099998  109.099998
# 2022-12-28  110.349998  116.269997  108.239998  112.709999  112.709999
# 2022-12-29  120.389999  123.570000  117.500000  121.820000  121.820000
# 2022-12-30  119.949997  124.480003  119.750000  123.180000  123.180000
#
#                Volume
# Date
# 2022-01-03  103931400
# 2022-01-04  100248300
# 2022-01-05   80119800
# ...

# %% [markdown]
# ### Question 2 - Extracting Tesla Revenue Data Using Webscraping - 1 Points

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt

url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/revenue.htm"
response = requests.get(url)

if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')
    tables = pd.read_html(str(soup.find_all("table")[1]))
    tsla_revenue = tables[0]
    tsla_revenue.columns = ["Date", "Revenue"]
    tsla_revenue["Revenue"] = tsla_revenue["Revenue"].str.replace(',|\$', "", regex=True)
    tsla_revenue.dropna(inplace=True)
    tsla_revenue = tsla_revenue[tsla_revenue['Revenue'] != ""]
    print(tsla_revenue)
    tsla_revenue['Revenue'] = pd.to_numeric(tsla_revenue['Revenue'])


else:
    print(f"Failed to download webpage. Status code: {response.status_code}")
# Out:
#           Date Revenue
# 0   2022-09-30   21454
# 1   2022-06-30   16934
# 2   2022-03-31   18756
# 3   2021-12-31   17719
# 4   2021-09-30   13757
# 5   2021-06-30   11958
# 6   2021-03-31   10389
# 7   2020-12-31   10744
# 8   2020-09-30    8771
# 9   2020-06-30    6036
# 10  2020-03-31    5985
# 11  2019-12-31    7384
# 12  2019-09-30    6303
# 13  2019-06-30    6350
# 14  2019-03-31    4541
# 15  2018-12-31    7226
# 16  2018-09-30    6824
# 17  2018-06-30    4002
# 18  2018-03-31    3409
# 19  2017-12-31    3288
# 20  2017-09-30    2985
# 21  2017-06-30    2790
# 22  2017-03-31    2696
# 23  2016-12-31    2285
# 24  2016-09-30    2298
# 25  2016-06-30    1270
# 26  2016-03-31    1147
# 27  2015-12-31    1214
# 28  2015-09-30     937
# 29  2015-06-30     955
# 30  2015-03-31     940
# 31  2014-12-31     957
# 32  2014-09-30     852
# 33  2014-06-30     769
# 34  2014-03-31     621
# 35  2013-12-31     615
# 36  2013-09-30     431
# 37  2013-06-30     405
# 38  2013-03-31     562
# ...

# %% [markdown]
# ### Question 3 - Extracting GameStop Stock Data Using yfinance - 2 Points

# %%
gamestop_stock_data = yf.download('GME', start='2022-01-01', end='2023-01-01')
gamestop_stock_data
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2022-01-03  37.307499  39.845001  37.302502  38.209999  38.209999   5654800
# 2022-01-04  38.042500  38.247501  35.762501  37.227501  37.227501   7339600
# 2022-01-05  37.097500  37.212502  32.287498  32.342499  32.342499  13585600
# 2022-01-06  33.209999  34.424999  30.285000  32.757500  32.757500  24206000
# 2022-01-07  39.942501  40.077499  33.125000  35.154999  35.154999  48549200
# ...               ...        ...        ...        ...        ...       ...
# 2022-12-23  20.000000  20.629999  19.650000  20.080000  20.080000   3174800
# 2022-12-27  19.910000  19.990000  18.000000  18.200001  18.200001   4233000
# 2022-12-28  18.290001  18.700001  16.980000  17.920000  17.920000   5672000
# 2022-12-29  18.120001  18.570000  17.750000  18.330000  18.330000   3442800
# ...

# %% [markdown]
# ### Question 4 - Extracting GameStop Revenue Data Using Webscraping - 1 Points

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt

url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/stock.html"
response = requests.get(url)

if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')
    tables = pd.read_html(str(soup.find_all("table")[1]))
    gamestop_revenue = tables[0]
    gamestop_revenue.columns = ["Date", "Revenue"]
    gamestop_revenue["Revenue"] = gamestop_revenue["Revenue"].str.replace(',|\$', "", regex=True)
    gamestop_revenue.dropna(inplace=True)
    gamestop_revenue = gamestop_revenue[gamestop_revenue['Revenue'] != ""]
    print(gamestop_revenue)
    gamestop_revenue['Revenue'] = pd.to_numeric(gamestop_revenue['Revenue'])


else:
    print(f"Failed to download webpage. Status code: {response.status_code}")
# Out:
#           Date Revenue
# 0   2020-04-30    1021
# 1   2020-01-31    2194
# 2   2019-10-31    1439
# 3   2019-07-31    1286
# 4   2019-04-30    1548
# ..         ...     ...
# 57  2006-01-31    1667
# 58  2005-10-31     534
# 59  2005-07-31     416
# 60  2005-04-30     475
# 61  2005-01-31     709
#
# [62 rows x 2 columns]

# %% [markdown]
# ### Question 5 - Tesla Stock and Revenue Dashboard - 2 Points

# %%
    tsla_revenue.sort_values(by='Date', inplace=True)
    plt.figure(figsize=(10, 6))
    plt.plot(tsla_revenue['Date'], tsla_revenue['Revenue'], marker='o', linestyle='-', color='b')
    plt.title('Tsla Revenue Over Time')
    plt.xlabel('Date')
    plt.ylabel('Revenue')
    plt.xticks()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Question 6 - GameStop Stock and Revenue Dashboard- 2 Points

# %%
    gamestop_revenue.sort_values(by='Date', inplace=True)
    plt.figure(figsize=(10, 6))
    plt.plot(gamestop_revenue['Date'], gamestop_revenue['Revenue'], marker='o', linestyle='-', color='b')
    plt.title('GameStop Revenue Over Time')
    plt.xlabel('Date')
    plt.ylabel('Revenue')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.tight_layout()
    plt.show()
